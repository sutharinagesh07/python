# %% [markdown]
# # **TASK**
# # **1) WHAT IS PYTHON**
# # **2) HISTORY OF PYTHON**
# # **3) WHY WE NEED TO USE PYTHON**
# # **4) APPLICTAION PYTHON**
# # **5) EXPLAIN ABOUT KEYWORDS AND IMPLEMENT**
# # **6)EXPLAIN ABOUT COMMENTS AND EXAMPLE**
# # **7) EXPLAIN INDETAIL ABOUT VARIABLES WITH EXAMPLES AND RULES**

# %% [markdown]
# # **1) WHAT IS PYTHON**
# - Python is an interpreted, object-oriented, high-level programming language with dynamic semantics.
# - Python is one of the easiest programming languages to learn, largely due to its object-oriented nature and simple syntax.
# - Python is used to build websites and web applications

# %% [markdown]
# # **2) HISTORY OF PYTHON**
#  -  Python was created by Guido van Rossum, and first released on February 20, 1991.
# # - **versions of python**
#
#  - 3.13 prerelease 2024-10-01 (planned) 2029-10 PEP 719.
#  - 3.12 bugfix 2023-10-02 2028-10 PEP 693.
#  -3.11 security 2022-10-24 2027-10 PEP 664.
#  -3.10 security 2021-10-04 2026-10 PEP 619.
#  -3.9 security 2020-10-05 2025-10 PEP 596.
#  -3.8 security 2019-10-14 2024-10 PEP 569.

# %% [markdown]
# # **3) WHY WE NEED TO USE PYTHON**
#  -  Python is commonly used for developing websites and software, task automation, data analysis, and data visualisation.
#  -  its versatility, extensive libraries, data science capabilities, artificial intelligence (AI), machine learning (ML), web development, scripting, automation, cross-platform compatibility, open-source nature, ease of learning.
#  - Python is the Easiest Programming Language to Learn.

# %% [markdown]
# # **4) APPLICTAION PYTHON**
#   -   **Game development**
#
#  Python's intuitive syntax and ease of use make it a popular choice for hobbyists and indie game developers. The Pygame library provides a framework for building 2D games and interactive applications.
#   -**Artificial intelligence**
#
#  Python is used for a variety of AI applications, including machine learning, natural language processing, and artificial neural networks
#   -**Data and information visualization**
#
#  Python provides a variety of graphic libraries to create visual presentations based on data.

# %% [markdown]
# # **5) EXPLAIN ABOUT KEYWORDS AND IMPLEMENT**
# -  Keywords in Python are reserved words that have a specific purpose and function in the language. They are used to define the syntax and structure of Python code, and are different from built-in functions and types.

# %%
# prompt: # keywords

import keyword

print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# # **6)EXPLAIN ABOUT COMMENTS AND EXAMPLE**
# -  Python comments are simple sentences that we use to make the code easier to understand. They explain your way of thinking and describe every step that you take to solve a coding problem. These sentences are not read by the Python interpreter when it executes the code.
# - **single line comment**
#
#   Python single-line comment starts with the hashtag symbol (#) with no white spaces and lasts till the end of the line.
#
#  If the comment exceeds one line then put a hashtag on the next line and continue the Python Comment.
#
#  Python’s single-line comments are proved useful for supplying short explanations for variables, function declarations, and expressions. See the following code snippet demonstrating single line comment:

# %%
# sample comment
name = "geeksfogeeks"
print(name)
# Out:
# geeksfogeeks

# %% [markdown]
# # **7) EXPLAIN INDETAIL ABOUT VARIABLES WITH EXAMPLES AND RULES**
# -   A Python variable is a reserved memory location to store values.
# -   In other words, a variable in a python program gives data to the computer
#      for processing.
# -  Different data types in Python are Numbers, List, Tuple, Strings, Dictionary.
#
# # **rules**
#  Start with a letter or underscore
# Variable names must start with a letter or an underscore, but not a number.
#
# Use only certain characters
# Variable names can only contain letters, numbers, and underscores (A-z, 0-9, and _).
#
# Avoid spaces and special characters
# Variable names cannot contain spaces or special characters like $, (, or *.
#
# Avoid Python keywords
# Avoid using Python keywords like "if", "for", or "while" as variable names.
#
# Be case-sensitive
# Variable names are case-sensitive, so "age", "Age", and "AGE" are three different variables.
#
# Be descriptive
# Variable names should be descriptive and not too short or too long.
#
# Use snake_case
# Use lowercase letters and underscores to separate words in variable names

# %%
75+18+45
# Out:
# 138

# %%
245+356+789
# Out:
# 1390

# %%
350*14
# Out:
# 4900

# %%
x = 7
y = "lucky"
print(x)
print(y)
# Out:
# 7
# lucky
